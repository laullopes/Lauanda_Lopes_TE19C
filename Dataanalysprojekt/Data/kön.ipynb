# %%
import matplotlib.pyplot as plt 
import pandas as pd 

df = pd.read_csv("Gender_Data.csv")

# Antalet fall 
cases_M =[df.iloc[0,1]] 
cases_F = [df.iloc[1,1]]

Total_C = [cases_M, cases_F] 
labels = ["Men", "Woman"] # Försöka flytta på den och lägga till summan av alla 

plt.pie(Total_C, labels= labels, autopct='%1.1f%%', colors=["magenta", "cyan"]) # Ändra färgen  
plt.legend([cases_M, cases_F], title = "The number:")
plt.title("Total Cases of Woman and Men")
plt.show()

# Antalet döda 
deaths_M =[df.iloc[0,3]] 
deaths_F = [df.iloc[1,3]]

Total_D = [deaths_M, deaths_F]
labels = ["Men", "Woman"] # Försöka flytta på den och lägga till summan av alla 

plt.pie(Total_D, labels= labels, autopct='%1.1f%%', colors= ["grey", "hotpink"]) # Ändra färgen  
plt.legend([deaths_M , deaths_F], title = "The number:")
plt.title("Total Deaths of Woman and Men")
plt.show()


# Summan av båda 
summa_C = df["Total_Cases"].sum()
summa_D = df["Total_Deaths"].sum()

lista = [summa_C, summa_D]
labels = "Cases", "Deaths"

plt.pie(lista, labels= labels, autopct='%1.1f%%', colors= ["blue", "white"])
plt.title("Total Cases and Deaths in Total")
plt.legend([summa_C, summa_D], title = "The number:")
plt.show()
# Out:
# <ipython-input-51-6f0fab06bd7d>:13: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   plt.pie(Total_C, labels= labels, autopct='%1.1f%%', colors=["magenta", "cyan"]) # Ändra färgen
# <ipython-input-51-6f0fab06bd7d>:25: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   plt.pie(Total_D, labels= labels, autopct='%1.1f%%', colors= ["grey", "hotpink"]) # Ändra färgen
