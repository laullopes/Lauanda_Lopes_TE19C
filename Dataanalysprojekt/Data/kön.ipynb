# %%
import matplotlib.pyplot as plt 
import pandas as pd 

df = pd.read_csv("Gender_Data.csv")
fig, axs = plt.subplots(2,2, figsize=(10,10))

# Antalet fall 
cases_M =[df.iloc[0,1]] 
cases_F = [df.iloc[1,1]]
Total_C = [cases_M, cases_F] 
labels = ["Men", "Woman"] 

axs[0,0].pie(Total_C, labels= labels, autopct='%1.1f%%', colors=["magenta", "cyan"])
axs[0,0].legend([cases_M, cases_F], title = "The number:")
axs[0,0].set_title("Total Cases of Woman and Men")

# Antalet döda 
deaths_M =[df.iloc[0,3]] 
deaths_F = [df.iloc[1,3]]
Total_D = [deaths_M, deaths_F]
labels = ["Men", "Woman"] 

axs[1,0].pie(Total_D, labels= labels, autopct='%1.1f%%', colors= ["grey", "hotpink"])
axs[1,0].legend([deaths_M , deaths_F], title = "The number:")
axs[1,0].set_title("Total Deaths of Woman and Men")

# Summan av båda 
summa_C = df["Total_Cases"].sum()
summa_D = df["Total_Deaths"].sum()
lista = [summa_C, summa_D]
labels = "Cases", "Deaths"

axs[0,1].pie(lista, labels= labels, autopct='%1.1f%%', colors= ["gold", "white"])
axs[0,1].set_title("Total Cases and Deaths in Total")
axs[0,1].legend([summa_C, summa_D], title = "The number:")

icu_M = [df.iloc[0,2]]
icu_F = [df.iloc[1,2]]
Total_ICU = [icu_M, icu_F]
labels = ["Men", "Woman"]

axs[1,1].pie(lista, labels= labels, autopct='%1.1f%%', colors= ["blue", "pink"])
axs[1,1].set_title("Total ICU admissions")
axs[1,1].legend([icu_M, icu_F], title = "The number:")

plt.show()
# Out:
# <ipython-input-2-6d6b5bb9b5c1>:13: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   axs[0,0].pie(Total_C, labels= labels, autopct='%1.1f%%', colors=["magenta", "cyan"])
# <ipython-input-2-6d6b5bb9b5c1>:23: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   axs[1,0].pie(Total_D, labels= labels, autopct='%1.1f%%', colors= ["grey", "hotpink"])
