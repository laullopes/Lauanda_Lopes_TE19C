# %%
import pandas as pd 
import matplotlib.pyplot as plt 

df = pd.read_csv("Gender_Data.csv")

cases_M =[df.iloc[0,1]] 
cases_F = [df.iloc[1,1]]

Total_C = [cases_M, cases_F]
labels = ["Men", "Woman"] # Försöka flytta på den och lägga till summan av alla 
plt.pie(Total_C, labels= labels, autopct='%1.1f%%') # Ändra färgen  
plt.legend(["288.507", '319.641'])
plt.title("Total Cases of Woman and Men In Sweden")
plt.show()

print(df)

deaths_M =[df.iloc[0,3]] 
deaths_F = [df.iloc[1,3]]


Total_D = [deaths_M, deaths_F]
labels = ["Men", "Woman"] # Försöka flytta på den och lägga till summan av alla 
plt.pie(Total_D, labels= labels, autopct='%1.1f%%') # Ändra färgen  
plt.legend(["6657", "5771"])
plt.title("Total Deaths of Woman and Men In Sweden")
plt.show()
# Out:
# <ipython-input-79-55f211038b11>:11: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   plt.pie(Total_C, labels= labels, autopct='%1.1f%%') # Ändra färgen
# <ipython-input-79-55f211038b11>:24: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   plt.pie(Total_D, labels= labels, autopct='%1.1f%%') # Ändra färgen
#    Gender  Total_Cases  Total_ICU_Admissions  Total_Deaths
# 0    Male       288507                  3582          6657
# 1  Female       319641                  1411          5771
# [5771]
# [6657]

# %%
import matplotlib.pyplot as plt 

kön = [288507, 319641]
labels = ["Men", "Woman"]
plt.pie(kön, labels= labels, autopct='%1.1f%%')
plt.legend(["288.507", '319.641'])
plt.title("Total Deaths of Woman and Men In Sweden")
plt.show()
