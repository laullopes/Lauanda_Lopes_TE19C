# %%
import pandas as pd 

# Uppgift 1 - a) 
df = pd.read_csv("sysselsattning.csv", encoding="ISO-8859-1", header=1)
df_summa = df[df["sysselsättning"] == "förvärvsarbetande"]
total = df_summa["2019"].sum()
print(f"Antalet personer som förvärvsarbetade: {total}")

df = pd.read_csv("sysselsattning.csv", encoding="ISO-8859-1", header=1)
df_summa1 = df[df["sysselsättning"] == "ej förvärvsarbetande"]
total1 = df_summa1["2019"].sum()
print(f"Antalet personer som inte gjorde det: {total1} ")
# Out:
# Antalet personer som förvärvsarbetade: 2706467
# Antalet personer som inte gjorde det: 1070645

# %%
import matplotlib.pyplot as plt

# Uppgift 1 - c) 

df = pd.read_csv("sysselsattning.csv", encoding="ISO-8859-1", header=1)

lista = [total, total1]

antalet = "förvärvsarbetande", "ej förvärvsarbetande"

plt.pie(lista, labels= antalet)

plt.title("Andelen förvärvsarbetande och ej förvärvsarbetande")
plt.show()

# %%
import pandas as pd 

# Uppgift 2 - a)
df = pd.read_csv("sysselsattning.csv", encoding="ISO-8859-1", header=1)

df_män = df[df["kön"] == "män"]

#print(df_män)
ja = df_män.head(6)
# print(ja)
total_m = ja["2019"].sum()
print(f"Antalet män som förvärvsarbetade: {total_m}")



df_kvinnor = df[df["kön"] == "kvinnor"]
#print(df_kvinnor)
yes = df_kvinnor.head(6)
total_k = yes["2019"].sum()
print(f"Antalet kvinnor som förvärvsarbetade: {total_k}" )
# Out:
# Antalet män som förvärvsarbetade: 1403500
# Antalet kvinnor som förvärvsarbetade: 1302967

# %%
# Uppgift 2 - b)

# %%
df = pd.read_csv("sysselsattning.csv", encoding="ISO-8859-1", header=1)

df
# Out:
#           sysselsättning     ålder      kön    2019
# 0      förvärvsarbetande  16-19 år      män   58826
# 1      förvärvsarbetande  16-19 år  kvinnor   72847
# 2      förvärvsarbetande  20-24 år      män  192696
# 3      förvärvsarbetande  20-24 år  kvinnor  174074
# 4      förvärvsarbetande  25-29 år      män  293352
# 5      förvärvsarbetande  25-29 år  kvinnor  268587
# 6      förvärvsarbetande  30-34 år      män  303019
# 7      förvärvsarbetande  30-34 år  kvinnor  271975
# 8      förvärvsarbetande  35-39 år      män  280522
# 9      förvärvsarbetande  35-39 år  kvinnor  255391
# 10     förvärvsarbetande  40-44 år      män  275085
# 11     förvärvsarbetande  40-44 år  kvinnor  260093
# 12  ej förvärvsarbetande  16-19 år      män  176860
# 13  ej förvärvsarbetande  16-19 år  kvinnor  143432
# 14  ej förvärvsarbetande  20-24 år      män  117928
# 15  ej förvärvsarbetande  20-24 år  kvinnor  103001
# 16  ej förvärvsarbetande  25-29 år      män   86633
# ...
