# %%
import matplotlib.pyplot as plt 
import pandas as pd 

df = pd.read_csv("Gender_Data.csv")

fig, axs = plt.subplots(2,2, figsize=(10,10)) # Det här behövs för att visa greferna i ett enda fönstret 

# Antalet fall 
cases_Male =[df.iloc[0,1]] # med iloc kan man komma åt en specific rad och kolum 
cases_Female = [df.iloc[1,1]] 
Total_Cases = [cases_Male, cases_Female] # skapade en lista av antalet fallen för att sedan visualisera på en cirkeldiagram 
labels = "Men", "Woman"

axs[0,0].pie(Total_Cases, labels= labels, autopct='%1.1f%%', colors=["magenta", "cyan"]) 
axs[0,0].legend(Total_Cases, title = "The number") 
axs[0,0].set_title("Total Cases of Woman and Men") # Titeln på grafen 

# Antalet döda 
deaths_Male =[df.iloc[0,3]] 
deaths_Female = [df.iloc[1,3]]
Total_Deaths = [deaths_Male, deaths_Female]

axs[1,0].pie(Total_D, labels= labels, autopct='%1.1f%%', colors= ["grey", "hotpink"])
axs[1,0].legend(Total_Deaths, title = "The number")
axs[1,0].set_title("Total Deaths of Woman and Men")

# Summan av båda 
summa_Cases = df["Total_Cases"].sum() # Summan av fallen från både kvinnor och män 
summa_Deaths = df["Total_Deaths"].sum()
total = [summa_Cases, summa_Deaths]
labels = "Cases", "Deaths"

axs[0,1].pie(lista, labels= labels, autopct='%1.1f%%', colors= ["gold", "white"])
axs[0,1].set_title("Total Cases and Deaths in Total")
axs[0,1].legend(total, title = "The number")

# Antalet intesivvårdnade 
icu_Male = [df.iloc[0,2]]
icu_Female = [df.iloc[1,2]]
Total_ICU = [icu_Male, icu_Female]
labels = "Men", "Woman"

axs[1,1].pie(lista, labels= labels, autopct='%1.1f%%', colors= ["blue", "pink"])
axs[1,1].set_title("Total ICU admissions")
axs[1,1].legend(Total_ICU, title = "The number")

plt.show()
# Out:
# <ipython-input-9-8dfe346055b3>:14: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   axs[0,0].pie(Total_C, labels= labels, autopct='%1.1f%%', colors=["magenta", "cyan"])
# <ipython-input-9-8dfe346055b3>:23: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   axs[1,0].pie(Total_D, labels= labels, autopct='%1.1f%%', colors= ["grey", "hotpink"])

# %%
# PLOTLY
